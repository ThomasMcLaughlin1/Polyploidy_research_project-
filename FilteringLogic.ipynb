# %% [markdown]
# ## VCF → Consensus FASTA Pipeline: Filtering Logic
#
# We'll only apply simple SNPs where:
# - Top allele frequency > 5%
# - It is at least 30% more common than the second allele
# - It's a 1-to-1 SNP (not an indel or complex variant)

# %%
af_values = [af] if isinstance(af, float) else list(af)
allele_data = sorted(zip(alt, af_values), key=lambda x: x[1], reverse=True)

top_alt, top_af = allele_data[0]
second_af = allele_data[1][1] if len(allele_data) > 1 else 0.0

# Filters
if top_af <= 0.05 or (top_af - second_af) < 0.3:
    continue
if len(top_alt) != 1 or len(ref) != 1:
    continue
